# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
plt.figure(figsize=(14,8))
plt.scatter(df["Position"], df["Intensity"])
plt.title("Intensity Vs Position")
plt.xlabel("Position in mm")
plt.ylabel("Intensity in $\mu A$");
