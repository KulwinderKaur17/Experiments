# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd .read_csv("CuSo4.csv")
df.head()
# Out:
#         x-axis                   1                 2
# 0       second                Volt              Volt
# 1     +0.0E+00  +35.7701001167E+00  -112.9648238E-03
# 2   +500.0E-09  +35.7701001167E+00  -112.7589947E-03
# 3  +1.0000E-06  +35.7701001167E+00  -112.5531656E-03
# 4  +1.5000E-06  +35.7701001167E+00  -112.3473364E-03

# %%
df = df.iloc[1:]

# %%
df["1"] = df["1"].apply(lambda x : float(x))

# %%
df["2"] = df["2"].apply(lambda x : float(x))

# %%
df["x-axis"] = df["x-axis"].apply(lambda x: float(x))

# %%
plt.rcParams["figure.figsize"] = (10,8)

# %%
plt.scatter(df["1"], df["2"])

# %%
plt.scatter(df["x-axis"], df["1"])

# %%
plt.scatter(df["x-axis"], df["2"])
